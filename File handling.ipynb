# %% [markdown]
# # File handling

# %%
open("C:\Users\sss\Downloads\mbox.txt")
# Out:
#   File "C:\Users\sss\AppData\Local\Temp\ipykernel_10924\2974722163.py", line 1
#     open("C:\Users\sss\Downloads\mbox.txt")
#                                           ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
r"C:\Users\sss\Downloads\mbox.txt"
# Out:
# 'C:\\Users\\sss\\Downloads\\mbox.txt'

# %%
open(r"C:\Users\sss\Downloads\mbox.txt")
# Out:
# <_io.TextIOWrapper name='C:\\Users\\sss\\Downloads\\mbox.txt' mode='r' encoding='cp1252'>

# %%
file=open(r"C:\Users\sss\Downloads\mbox.txt")

# %%
open(r"C:\Users\sss\Downloads\mbox.txt",'rb') #read binary
# Out:
# <_io.BufferedReader name='C:\\Users\\sss\\Downloads\\mbox.txt'>

# %%
open(r"C:\Users\sss\Downloads\mbox.txt",'wb')# write binary

# %%
file=open(r"C:\Users\sss\Downloads\mbox.txt")
file
# Out:
# <_io.TextIOWrapper name='C:\\Users\\sss\\Downloads\\mbox.txt' mode='r' encoding='cp1252'>

# %%
file.close()

# %%
file.closed
# Out:
# True

# %% [markdown]
# # method :1.using read()

# %%
file=open(r"C:\Users\sss\Downloads\mbox.txt").read()
file[:100]
# file read()
# Out:
# 'From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008\nReturn-Path: <postmaster@collab.sakaiprojec'

# %%
file=open(r"C:\Users\sss\Downloads\mbox.txt").read()[:100]

# %%
for i in file: 
    print(i) #instead of this use below
# Out:
# F
# r
# o
# m
#
# s
# t
# e
# p
# h
# e
# n
# .
# m
# a
# r
# q
# u
# a
# r
# d
# @
# u
# c
# t
# .
# a
# c
# .
# z
# a
#
# S
# a
# t
#
# J
# a
# n
#
#
# 5
#
# 0
# 9
# :
# 1
# 4
# :
# 1
# 6
#
# 2
# 0
# 0
# 8
#
#
# R
# e
# t
# u
# r
# n
# -
# P
# a
# t
# h
# :
#
# <
# p
# o
# s
# t
# m
# a
# s
# t
# e
# r
# @
# c
# o
# l
# l
# a
# b
# .
# s
# a
# k
# a
# i
# p
# r
# o
# j
# e
# c

# %%
for line in open(r"C:\Users\sss\Downloads\mbox.txt").readlines():
    print(line)
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
#
# Return-Path: <postmaster@collab.sakaiproject.org>
#
# Received: from murder (mail.umich.edu [141.211.14.90])
#
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
#
# 	 Sat, 05 Jan 2008 09:14:16 -0500
#
# X-Sieve: CMU Sieve 2.3
#
# Received: from murder ([unix socket])
#
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
#
# 	 Sat, 05 Jan 2008 09:14:16 -0500
#
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
#
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
#
# 	Sat, 5 Jan 2008 09:14:15 -0500
#
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
#
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
#
# 	 5 Jan 2008 09:14:10 -0500
#
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
#
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
#
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
#
# ...

# %%
file=open(r"C:\Users\sss\Downloads\mbox-short.txt")

# %%
file=open(r"C:\Users\sss\Downloads\mbox-short.txt")

for line in file.readlines():
    if line.startswith('From'): # only get from emails
         print(line.strip())
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# From: stephen.marquard@uct.ac.za
# From louis@media.berkeley.edu Fri Jan  4 18:10:48 2008
# From: louis@media.berkeley.edu
# From zqian@umich.edu Fri Jan  4 16:10:39 2008
# From: zqian@umich.edu
# From rjlowe@iupui.edu Fri Jan  4 15:46:24 2008
# From: rjlowe@iupui.edu
# From zqian@umich.edu Fri Jan  4 15:03:18 2008
# From: zqian@umich.edu
# From rjlowe@iupui.edu Fri Jan  4 14:50:18 2008
# From: rjlowe@iupui.edu
# From cwen@iupui.edu Fri Jan  4 11:37:30 2008
# From: cwen@iupui.edu
# From cwen@iupui.edu Fri Jan  4 11:35:08 2008
# From: cwen@iupui.edu
# From gsilver@umich.edu Fri Jan  4 11:12:37 2008
# From: gsilver@umich.edu
# From gsilver@umich.edu Fri Jan  4 11:11:52 2008
# From: gsilver@umich.edu
# From zqian@umich.edu Fri Jan  4 11:11:03 2008
# From: zqian@umich.edu
# From gsilver@umich.edu Fri Jan  4 11:10:22 2008
# From: gsilver@umich.edu
# From wagnermr@iupui.edu Fri Jan  4 10:38:42 2008
# From: wagnermr@iupui.edu
# ...

# %%
try:
    file=open('documents.txt','w') 
    file.write(f'hello world\n') 
    file.write(f'How are you?') 
finally:
    file.close()

# %%
file=open('documents.txt','w')
file.close()

# %%
# append()
var="chaitanya"
try:
    file=open('documents.txt','a') 
    file.write(f'Hello\n {var}')
    file.write(' World') 
finally:
    file.close()

# %%
file=open('documents.txt','r')
filelist=file.readlines()
print(filelist)
file.close()
# Out:
# ['Hello\n', ' chaitanya WorldHello\n', ' chaitanya World']

# %%
# The librarian of a library wants to keep a record of books .write a program to store the information about the books in a file
# and also write a function to search for a book based on  the name of the book,author or ISBN.
def books():
    try:
        file=open('books.txt','a')
        while True:
            value=input(f'''Enter the details in following format: \n ''' )
            if value=='done':break 
            else:
                file.write(f'{value}\n') 
    finally:
        file.close()

# %%
books()
# Out:
# Enter the details in following format:
#  chaitanya
# Enter the details in following format:
#  vasundhara
# Enter the details in following format:
#  krishna
# Enter the details in following format:
#  krishna chaitanya
# Enter the details in following format:
#  vasundhara chaitanya
# Enter the details in following format:
#  done

# %%
def search():
    value=None
    inp=input(f'select the relevant option.\nEnter 1 to search book with author\nEnter 2 to search with book Name\n 3 to search with book with ISBN') 
    if inp== '1':
        value=input("Enter author Name: ").lower()
    elif inp== '2':
        value=input("Enter book Name: ").lower()
    elif inp== '3':
        value=input("Enter ISBN number: ").lower()
    else:
        value=None
        print('wrong input try again.')
              
    file=open('books.txt')          
    books=[]
    for i in file:
         if value in i.lower():
                books.append(i.strip())
    if len(books)>=1:
              return books
    else:
        return 'No records found'
        file.close()

# %%
search()
# Out:
# select the relevant option.
# Enter 1 to search book with author
# Enter 2 to search with book Name
#  3 to search with book with ISBN1
# Enter author Name: chaitanya
# ['chaitanya', 'krishna chaitanya', 'vasundhara chaitanya']

# %% [markdown]
# # Exception handling

# %% [markdown]
# # Exceptions and errors

# %%
def fun():
    x=1/0
    print(x)

# %%
fun()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21972\529771688.py in <module>
# ----> 1 fun()
#
# ~\AppData\Local\Temp\ipykernel_21972\3254647555.py in fun()
#       1 def fun():
# ----> 2     x=1/0
#       3     print(x)
#
# ZeroDivisionError: division by zero

# %%
funny-1
# Out:
# 0

# %%
funny=1

# %%
from sklearn.linear_model import LinearRegression
X=[i for i in range(100)]
Y=[i for i in range(50)]
LinearRegression(X,Y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21972\4030991772.py in <module>
#       2 X=[i for i in range(100)]
#       3 Y=[i for i in range(50)]
# ----> 4 LinearRegression(X,Y)
#
# TypeError: __init__() takes 1 positional argument but 3 were given

# %%
a=int(input("Enter the number"))
print("The number is:",a)
# Out:
# Enter the numberhello
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10028\2999003299.py in <module>
# ----> 1 a=int(input("Enter the number"))
#       2 print("The number is:",a)
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
str.CAptilize()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21972\3687919310.py in <module>
# ----> 1 str.CAptilize()
#
# AttributeError: type object 'str' has no attribute 'CAptilize'

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
# ...

# %%
'str'[2]=4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21972\321167168.py in <module>
# ----> 1 'str'[2]=4
#
# TypeError: 'str' object does not support item assignment

# %%
t=(1,2,3,4)
t[2]=5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21972\3821571905.py in <module>
#       1 t=(1,2,3,4)
# ----> 2 t[2]=5
#
# TypeError: 'tuple' object does not support item assignment

# %%
var='str'[0]+'4'+'str'[-1]
var
# Out:
# 's4r'

# %%
var1='tuple'[0]+'9'+'tuple'[-1]
var1
# Out:
# 't9e'

# %%
var2='dict'[0]+'8'+'dict'[-1]
var2
# Out:
# 'd8t'

# %%
num1=int(input("Enter first number"))
num2=int(input("Enter second number"))

print(num1+num2)
# Out:
# Enter first numberone
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21972\2126814722.py in <module>
# ----> 1 num1=int(input("Enter first number"))
#       2 num2=int(input("Enter second number"))
#       3
#       4 print(num1+num2)
#
# ValueError: invalid literal for int() with base 10: 'one'

# %%
try:
    num1=int(input("Enter first number"))
    num2=int(input("Enter second number"))
except:
    print("enter a number")
# Out:
# Enter first numberone
# enter a number

# %%
int('one')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21972\2369944164.py in <module>
# ----> 1 int('one')
#
# ValueError: invalid literal for int() with base 10: 'one'

# %%
try:
    num1=int(input("Enter first number"))
    num2=int(input("Enter second number"))
    raise ValueError('except number received alphabets') 
except ValueError as ve:
    print("ve")
    print("ExceptionError",ve)
# Out:
# Enter first number10
# Enter second numberone
# ve
# ExceptionError invalid literal for int() with base 10: 'one'

# %%
#Wap to make input from the user and print divison table
a=int(input("enter a numrator"))
b=int(input("enter a divisor"))
c=a/b

print("the division is:",c)
# Out:
# enter a numrator10
# enter a divisor0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21972\1123077096.py in <module>
#       2 a=int(input("enter a numrator"))
#       3 b=int(input("enter a divisor"))
# ----> 4 c=a/b
#       5
#       6 print("the division is:",c)
#
# ZeroDivisionError: division by zero

# %%
try:
    a=int(input("enter a numerator"))
    b=int(input("enter a divisor"))
    c=a/b
except:
    print('cannot divide by zero')
# Out:
# enter a numerator10
# enter a divisor0
# cannot divide by zero

# %%
# multiplication 
a=int(input("enter a number"))
b=int(input("enter a number"))
c=a**b

print("the power is:",c)
# Out:
# enter a number0
# enter a number-1
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21972\2355954692.py in <module>
#       2 a=int(input("enter a number"))
#       3 b=int(input("enter a number"))
# ----> 4 c=a**b
#       5
#       6 print("the power is:",c)
#
# ZeroDivisionError: 0.0 cannot be raised to a negative power

# %%
try:
    a=int(input("enter a number:"))
    b=int(input("enter a number:"))
    c=a**b
except:
    print("zero cannot raised negative value")
# Out:
# enter a number:0
# enter a number:-1
# zero cannot raised negative value

# %%
try:
    1/s 
except:
    print('s is not defined')
finally:
    print("this is compulsory")
# Out:
# s is not defined
# this is compulsory

# %% [markdown]
# # custom exception

# %%
# define python user-defined exceptions
class Error(Exception):
    """ Base class for other exceptions"""
    pass
class ValueTooSmallError(Error):
    """Raised when the input value is too small"""
    pass
class ValueTooLargeError(Error):
    """Raised when the input value is too large """
    pass
# our main program
## user guesses a number until he/she gets it right
number=10
while True:
    try:
        i_num = int(input("Enter a number : "))
        if i_num < number:
            raise ValueTooSmallError
        elif i_num > number:
            raise ValueTooLargeError
        break 
    except ValueTooSmallError:
        print("This value is Too small, try again!")
    except ValueTooLargeError:  
        print("This value is too large,try again!")
        print()
print("congratulations! You guessed it correctly.")
# Out:
# Enter a number : 1234
# This value is too large,try again!
#
# Enter a number : 56
# This value is too large,try again!
#
# Enter a number : 9
# This value is Too small, try again!
# Enter a number : 10
# congratulations! You guessed it correctly.

# %% [markdown]
# # Map,filter

# %%
x=['Name','Robert','Amy','Andrew']

# %%
map(len,x)

# %%
list(map(len,x))
# Out:
# [4, 6, 3, 6]

# %%
#def kelvin(n):
#    return n+273

# %%
# map(func,collect)
celcius=[23,54,32,87,54,12,45,34]

kelvin_=list(map(lambda x:x+273,celcius))
kelvin_
# Out:
# [296, 327, 305, 360, 327, 285, 318, 307]

# %%
# covert celcius to fahrenheit
celcius=[23,54,32,87,54,12,45,34]
fahrenhiet_=list(map(lambda x:x*(9/5)+32,celcius))
fahrenhiet_
# Out:
# [73.4, 129.2, 89.6, 188.6, 129.2, 53.6, 113.0, 93.2]

# %%
# filter(function,data structure)
import random
event=[random.randint(15,70) for i in range(100)]

# %%
def entry(n):
    return n>21

# %%
entry(20)
# Out:
# False

# %%
permitted=list(filter(entry,event))
permitted
# Out:
# [32,
#  46,
#  63,
#  36,
#  60,
#  32,
#  41,
#  36,
#  37,
#  65,
#  64,
#  59,
#  29,
#  66,
#  26,
#  44,
#  36,
#  27,
#  69,
#  52,
#  64,
#  50,
#  60,
#  47,
#  67,
#  56,
#  22,
#  54,
#  62,
#  55,
#  70,
#  39,
#  46,
#  53,
#  65,
#  54,
#  40,
#  37,
#  35,
#  24,
#  48,
#  57,
#  59,
#  58,
#  61,
#  41,
#  42,
#  47,
#  35,
#  58,
#  42,
#  51,
#  26,
#  39,
#  45,
#  41,
#  38,
#  39,
#  53,
#  60,
#  47,
#  43,
#  40,
#  46,
#  36,
#  52,
#  26,
#  31,
#  54,
#  66,
#  47,
#  30,
#  34,
#  23,
#  52,
#  30,
#  59,
#  69,
#  39,
#  37,
#  34,
#  70,
#  62,
#  40,
#  62,
#  26,
#  65,
#  44]

# %%
permitted=list(filter(lambda x:x>21,event))
permitted
# Out:
# [32,
#  46,
#  63,
#  36,
#  60,
#  32,
#  41,
#  36,
#  37,
#  65,
#  64,
#  59,
#  29,
#  66,
#  26,
#  44,
#  36,
#  27,
#  69,
#  52,
#  64,
#  50,
#  60,
#  47,
#  67,
#  56,
#  22,
#  54,
#  62,
#  55,
#  70,
#  39,
#  46,
#  53,
#  65,
#  54,
#  40,
#  37,
#  35,
#  24,
#  48,
#  57,
#  59,
#  58,
#  61,
#  41,
#  42,
#  47,
#  35,
#  58,
#  42,
#  51,
#  26,
#  39,
#  45,
#  41,
#  38,
#  39,
#  53,
#  60,
#  47,
#  43,
#  40,
#  46,
#  36,
#  52,
#  26,
#  31,
#  54,
#  66,
#  47,
#  30,
#  34,
#  23,
#  52,
#  30,
#  59,
#  69,
#  39,
#  37,
#  34,
#  70,
#  62,
#  40,
#  62,
#  26,
#  65,
#  44]

# %%
21<22
# Out:
# True

# %%
#filter(function,data structure)

# %% [markdown]
# # Python object-oriented concepts
